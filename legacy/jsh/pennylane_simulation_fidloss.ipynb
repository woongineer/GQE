# %%
from src.model import GPT, GPTConfig
import torch
import torch.nn as nn
import numpy as np
from torch.nn import functional as F
from Pennylane.Circuit_generate import QuantumEmbedding
from src.dataload import get_data
from torch.utils.data import DataLoader, TensorDataset
import pennylane as qml
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import torchvision
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Data Loading

# %%
transform = torchvision.transforms.ToTensor()

# Download training data into data folder
training_set = torchvision.datasets.FashionMNIST(root='./data', train=True, transform=transform, download=True)

# Download test data into data folder
test_set = torchvision.datasets.FashionMNIST(root='./data', train=False, transform=transform, download=True)

# %%
# Get the training set features and labels
x_train = training_set.data
y_train = training_set.targets

# Get the test set features and labels
x_test = test_set.data
y_test = test_set.targets

# Rescale the images from [0, 255] to the [0, 1] range.
x_train = x_train / 255.0
x_test = x_test / 255.0

print("Number of samples in the training set:", len(x_train))
print("Number of samples in the test set:", len(x_test))
# Out:
# Number of samples in the training set: 60000
# Number of samples in the test set: 10000

# %%
# Use PCA to transform each image to an n-dimensional vector
n_components = 10

# Convert tensors to numpy arrays
x_train = x_train.numpy()
x_test = x_test.numpy()

# Number of train and test samples
num_train = x_train.shape[0]
num_test = x_test.shape[0]

# Flatten images to 1D arrays
x_train = np.reshape(x_train, (num_train, -1))
x_test = np.reshape(x_test, (num_test, -1))

# Run PCA
pca = PCA(n_components=n_components)
x_train = pca.fit_transform(x_train)
x_test = pca.fit_transform(x_test)

# Normalize each feature in dataset
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)


print(f'New number of features per datapoint:', len(x_train[0]))
# Out:
# New number of features per datapoint: 10

# %% [markdown]
# ## Hyperparameter Setting

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
n,p = x_train.shape

"""If use qubit matching, set num_qubits = p  otherwise, it is up to user's choice"""
num_qubits = 4
op_pool_size = p*4*num_qubits
max_gate = 12           # senario legth

# TensorDataset을 사용하여 데이터셋 생성
X_train_tensor = torch.tensor(x_train, dtype=torch.float32).to(device)
y_train_tensor = torch.tensor(y_train, dtype=torch.int32).to(device)

X_test_tensor = torch.tensor(x_test, dtype=torch.float32).to(device)
y_test_tensor = torch.tensor(y_test, dtype=torch.int32).to(device)

# TensorDataset을 사용하여 데이터셋 생성
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
# Out:
# C:\Users\detra\AppData\Local\Temp\ipykernel_7092\342494363.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train_tensor = torch.tensor(y_train, dtype=torch.int32).to(device)
# C:\Users\detra\AppData\Local\Temp\ipykernel_7092\342494363.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test_tensor = torch.tensor(y_test, dtype=torch.int32).to(device)

# %%
## Define quantum embedding circuit
dev = qml.device('default.qubit', wires=num_qubits)

@qml.qnode(dev, interface='torch')
def quantum_circuit(tokens, num_qubits, data):
    QuantumEmbedding(tokens, num_qubits, data)
    return qml.state()

# %%
def state_subsequnce(token, num_qubits, data_set):
    states = []
    for i in range(len(token)):
        if i ==0:
            pass
        else:
            sub_token = token[:i]
            for data in data_set:
                state = quantum_circuit(sub_token, num_qubits, data)
                states.append(state)
    return np.array(states).reshape(-1, data_set.shape[0], num_qubits**2)

# %%
def get_sub_energy(sub_states, labels):
    energies = []
    for states in sub_states:
        states_conj = np.conj(states)
        inner_prod = np.matmul(states_conj, states.T)
        fid_mat = np.abs(inner_prod)**2
        
        labels = labels.reshape(-1)
        label_prod = np.outer(labels, labels)

        loss_mat = (fid_mat - 0.5 * (1 + label_prod))**2
        indices = np.tril_indices(len(labels), k=1)
        loss_val = loss_mat[indices[0], indices[1]]
        loss = np.mean(loss_val)
        energies.append(loss)
    return np.array(energies)

# %%
def get_svm_acc(sub_states, labels, gamma):
    energies = []
    labels = labels.reshape(-1)
    for states in sub_states:
        states = np.hstack((states.real, states.imag))
        svm = SVC(kernel='rbf', gamma=gamma)
        svm.fit(states, labels)
        predict = svm.predict(states)
        acc = accuracy_score(predict, labels)
        energies.append(acc)

    return 1 - np.array(energies)

# %%
class GPTQE(GPT):
    def forward(self, idx):
        device = idx.device
        b, t = idx.size()
        pos = torch.arange(0, t, dtype=torch.long, device=device) # shape (t)

        # forward the GPT model itself
        tok_emb = self.transformer.wte(idx) # token embeddings of shape (b, t, n_embd)
        pos_emb = self.transformer.wpe(pos) # position embeddings of shape (t, n_embd)
        x = self.transformer.drop(tok_emb + pos_emb)
        for block in self.transformer.h:
            x = block(x)
        x = self.transformer.ln_f(x)
        logits = self.lm_head(x)
        return logits

    def calculate_loss(self, tokens, energies):
        current_tokens, next_tokens = tokens[:, :-1], tokens[:, 1:]
        # calculate the logits for the next possible tokens in the sequence
        logits = self(current_tokens)
        # get the logit for the actual next token in the sequence
        next_token_mask = torch.nn.functional.one_hot(
            next_tokens, num_classes=self.config.vocab_size
        )
        next_token_logits = (logits * next_token_mask).sum(axis=2)
        # calculate the cumulative logits for each subsequence
        cumsum_logits = torch.cumsum(next_token_logits, dim=1)
        # match cumulative logits to subsequence energies
        loss = torch.mean(torch.square(cumsum_logits - energies))
        return loss

    @torch.no_grad()
    def generate(self, n_sequences, max_new_tokens, temperature=1.0, device="cpu"):
        idx = torch.zeros(size=(n_sequences, 1), dtype=int, device=device)
        total_logits = torch.zeros(size=(n_sequences, 1), device=device)
        for _ in range(max_new_tokens):
            # if the sequence context is growing too long we must crop it at block_size
            idx_cond = idx if idx.size(1) <= self.config.block_size else idx[:, -self.config.block_size:]
            # forward the model to get the logits for the index in the sequence
            logits = self(idx_cond)
            # pluck the logits at the final step
            logits = logits[:, -1, :]
            # set the logit of the first token so that its probability will be zero
            logits[:, 0] = float("inf")
            # apply softmax to convert logits to (normalized) probabilities and scale by desired temperature
            probs = F.softmax(-logits / temperature, dim=-1)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1)
            # # Accumulate logits
            total_logits += torch.gather(logits, index=idx_next, dim=1)
            # append sampled index to the running sequence and continue
            idx = torch.cat((idx, idx_next), dim=1)
        return idx, total_logits

# %%
gpt = GPTQE(GPTConfig(
    vocab_size = op_pool_size + 1,
    block_size = max_gate,
    dropout = 0.2,
    bias = False
))
opt = gpt.configure_optimizers(
    weight_decay=0.1, learning_rate=1e-9, betas=(0.9, 0.999), device_type="cpu"
)
# Out:
# number of parameters: 85.08M
# num decayed parameter tensors: 50, with 85,067,520 parameters
# num non-decayed parameter tensors: 25, with 19,200 parameters
# using fused AdamW: False

# %%
EPOCHS = 100
TEM = 1
R = 0.999
GAMMA = 1

train_losses = []
fid_losses = []

# %%
for i in range(EPOCHS):
    for X, Y in train_loader:
        Y = Y.detach().numpy()
        token, _ = gpt.generate(1, max_gate, TEM)
        states = state_subsequnce(*token, num_qubits, X)
        energy = get_svm_acc(states, Y, GAMMA) - 1
        energy_ten = torch.tensor(energy[None,:])
        loss = gpt.calculate_loss(token, energy_ten)
        loss.backward()
        opt.step()
        train_losses.append(loss.item())

        ev_tok, _ = gpt.generate(1, max_gate, 0.00001)
        ev_states = state_subsequnce(*ev_tok, num_qubits, X)
        energy = get_svm_acc(ev_states, Y, GAMMA)[-1]
        fid_losses.append(energy)
        print(f"Epochs: {i+1},  Loss : {loss.item():.4f}, Fid loss : {energy}")
    
    

    TEM = TEM * R
# Out:
# Epochs: 1,  Loss : 13.6074, Fid loss : 0.234375
# Epochs: 1,  Loss : 0.4335, Fid loss : 0.265625
# Epochs: 1,  Loss : 4.3322, Fid loss : 0.203125
# Epochs: 1,  Loss : 2.6888, Fid loss : 0.203125
# Epochs: 1,  Loss : 6.3409, Fid loss : 0.234375
# Epochs: 1,  Loss : 0.3068, Fid loss : 0.3125
# Epochs: 1,  Loss : 6.0140, Fid loss : 0.328125
# Epochs: 1,  Loss : 0.3331, Fid loss : 0.296875
# Epochs: 1,  Loss : 1.8564, Fid loss : 0.296875
# Epochs: 1,  Loss : 1.8991, Fid loss : 0.34375
# Epochs: 1,  Loss : 0.9712, Fid loss : 0.265625
# Epochs: 1,  Loss : 0.9872, Fid loss : 0.125
# Epochs: 1,  Loss : 4.6913, Fid loss : 0.078125
# Epochs: 1,  Loss : 1.9300, Fid loss : 0.3125
# Epochs: 1,  Loss : 0.2367, Fid loss : 0.1875
# Epochs: 1,  Loss : 0.8925, Fid loss : 0.265625
# Epochs: 1,  Loss : 0.7699, Fid loss : 0.359375
# Epochs: 1,  Loss : 3.0982, Fid loss : 0.21875
# Epochs: 1,  Loss : 2.5737, Fid loss : 0.25
# Epochs: 1,  Loss : 0.0911, Fid loss : 0.171875
# Epochs: 1,  Loss : 0.2072, Fid loss : 0.421875
# Epochs: 1,  Loss : 0.5996, Fid loss : 0.421875
# Epochs: 1,  Loss : 0.5657, Fid loss : 0.328125
# Epochs: 1,  Loss : 2.3073, Fid loss : 0.234375
# Epochs: 1,  Loss : 0.9396, Fid loss : 0.40625
# Epochs: 1,  Loss : 0.8519, Fid loss : 0.34375
# Epochs: 1,  Loss : 0.4448, Fid loss : 0.3125
# Epochs: 1,  Loss : 0.7793, Fid loss : 0.359375
# Epochs: 1,  Loss : 15.0366, Fid loss : 0.171875
# Epochs: 1,  Loss : 2.7914, Fid loss : 0.359375
# Epochs: 1,  Loss : 0.3583, Fid loss : 0.234375
# Epochs: 1,  Loss : 0.4946, Fid loss : 0.28125
# Epochs: 1,  Loss : 0.7023, Fid loss : 0.1875
# Epochs: 1,  Loss : 0.4567, Fid loss : 0.234375
# Epochs: 1,  Loss : 1.1232, Fid loss : 0.25
# Epochs: 1,  Loss : 0.5940, Fid loss : 0.34375
# Epochs: 1,  Loss : 1.9630, Fid loss : 0.203125
# Epochs: 1,  Loss : 2.1171, Fid loss : 0.1875
# Epochs: 1,  Loss : 0.2183, Fid loss : 0.15625
# Epochs: 1,  Loss : 0.2455, Fid loss : 0.25
# Epochs: 1,  Loss : 1.1640, Fid loss : 0.203125
# Epochs: 1,  Loss : 3.8418, Fid loss : 0.28125
# Epochs: 1,  Loss : 0.5200, Fid loss : 0.15625
# Epochs: 1,  Loss : 3.9918, Fid loss : 0.125
# Epochs: 1,  Loss : 5.2324, Fid loss : 0.421875
# Epochs: 1,  Loss : 0.6310, Fid loss : 0.28125
# Epochs: 1,  Loss : 0.5013, Fid loss : 0.296875
# Epochs: 1,  Loss : 0.7758, Fid loss : 0.484375
# Epochs: 1,  Loss : 0.9714, Fid loss : 0.109375
# Epochs: 1,  Loss : 0.8160, Fid loss : 0.296875
# Epochs: 1,  Loss : 3.2384, Fid loss : 0.21875
# Epochs: 1,  Loss : 6.1692, Fid loss : 0.25
# Epochs: 1,  Loss : 0.6999, Fid loss : 0.21875
# Epochs: 1,  Loss : 2.9883, Fid loss : 0.21875
# Epochs: 1,  Loss : 0.9331, Fid loss : 0.296875
# Epochs: 1,  Loss : 0.4559, Fid loss : 0.171875
# Epochs: 1,  Loss : 2.2873, Fid loss : 0.1875
# Epochs: 1,  Loss : 1.5604, Fid loss : 0.171875
# Epochs: 1,  Loss : 0.7403, Fid loss : 0.390625
# Epochs: 1,  Loss : 1.3161, Fid loss : 0.28125
# Epochs: 1,  Loss : 2.0926, Fid loss : 0.375
# Epochs: 1,  Loss : 3.8244, Fid loss : 0.1875
# Epochs: 1,  Loss : 0.4818, Fid loss : 0.25
# Epochs: 1,  Loss : 0.4486, Fid loss : 0.296875
# Epochs: 1,  Loss : 0.2197, Fid loss : 0.296875
# Epochs: 1,  Loss : 8.7692, Fid loss : 0.203125
# Epochs: 1,  Loss : 0.5078, Fid loss : 0.171875
# Epochs: 1,  Loss : 1.0599, Fid loss : 0.171875
# Epochs: 1,  Loss : 1.3998, Fid loss : 0.21875
# Epochs: 1,  Loss : 0.2800, Fid loss : 0.1875
# Epochs: 1,  Loss : 5.7127, Fid loss : 0.28125
# Epochs: 1,  Loss : 0.8577, Fid loss : 0.140625
# Epochs: 1,  Loss : 5.7521, Fid loss : 0.21875
# Epochs: 1,  Loss : 0.9089, Fid loss : 0.125
# Epochs: 1,  Loss : 0.5881, Fid loss : 0.265625
# Epochs: 1,  Loss : 0.2436, Fid loss : 0.3125
# Epochs: 1,  Loss : 1.6339, Fid loss : 0.359375
# Epochs: 1,  Loss : 0.3445, Fid loss : 0.203125
# Epochs: 1,  Loss : 3.2142, Fid loss : 0.25
# Epochs: 1,  Loss : 1.0077, Fid loss : 0.375
# Epochs: 1,  Loss : 0.1288, Fid loss : 0.390625
# Epochs: 1,  Loss : 0.4182, Fid loss : 0.1875
# Epochs: 1,  Loss : 1.3015, Fid loss : 0.25
# Epochs: 1,  Loss : 5.4045, Fid loss : 0.15625
# Epochs: 1,  Loss : 2.0302, Fid loss : 0.171875
# Epochs: 1,  Loss : 4.3917, Fid loss : 0.28125
# Epochs: 1,  Loss : 1.9311, Fid loss : 0.265625
# Epochs: 1,  Loss : 0.7522, Fid loss : 0.171875
# Epochs: 1,  Loss : 2.8570, Fid loss : 0.34375
# Epochs: 1,  Loss : 0.3760, Fid loss : 0.203125
# Epochs: 1,  Loss : 2.3108, Fid loss : 0.25
# Epochs: 1,  Loss : 0.2994, Fid loss : 0.3125
# Epochs: 1,  Loss : 9.2536, Fid loss : 0.1875
# Epochs: 1,  Loss : 1.7426, Fid loss : 0.125
# Epochs: 1,  Loss : 2.2322, Fid loss : 0.140625
# Epochs: 1,  Loss : 1.0650, Fid loss : 0.53125
# Epochs: 1,  Loss : 5.4447, Fid loss : 0.15625
# Epochs: 1,  Loss : 0.7995, Fid loss : 0.1875
# Epochs: 1,  Loss : 5.0042, Fid loss : 0.15625
# Epochs: 1,  Loss : 0.5181, Fid loss : 0.40625
# Epochs: 1,  Loss : 4.8525, Fid loss : 0.28125
# Epochs: 1,  Loss : 4.0535, Fid loss : 0.25
# Epochs: 1,  Loss : 6.0948, Fid loss : 0.171875
# Epochs: 1,  Loss : 1.8079, Fid loss : 0.1875
# Epochs: 1,  Loss : 0.7930, Fid loss : 0.15625
# Epochs: 1,  Loss : 2.7996, Fid loss : 0.28125
# Epochs: 1,  Loss : 1.3069, Fid loss : 0.21875
# Epochs: 1,  Loss : 0.4422, Fid loss : 0.359375
# Epochs: 1,  Loss : 3.3384, Fid loss : 0.265625
# Epochs: 1,  Loss : 1.5484, Fid loss : 0.265625
# Epochs: 1,  Loss : 0.2852, Fid loss : 0.4375
# Epochs: 1,  Loss : 10.7668, Fid loss : 0.1875
# Epochs: 1,  Loss : 0.9836, Fid loss : 0.1875
# Epochs: 1,  Loss : 5.8350, Fid loss : 0.21875
# Epochs: 1,  Loss : 1.8777, Fid loss : 0.375
# Epochs: 1,  Loss : 1.6265, Fid loss : 0.296875
# Epochs: 1,  Loss : 0.5739, Fid loss : 0.1875
# Epochs: 1,  Loss : 0.3871, Fid loss : 0.28125
# Epochs: 1,  Loss : 1.6532, Fid loss : 0.203125
# Epochs: 1,  Loss : 0.3717, Fid loss : 0.171875
# Epochs: 1,  Loss : 0.1035, Fid loss : 0.28125
# Epochs: 1,  Loss : 0.7465, Fid loss : 0.234375
# Epochs: 1,  Loss : 2.5197, Fid loss : 0.171875
# Epochs: 1,  Loss : 1.1519, Fid loss : 0.234375
# Epochs: 1,  Loss : 0.3702, Fid loss : 0.296875
# Epochs: 1,  Loss : 5.3273, Fid loss : 0.265625
# Epochs: 1,  Loss : 1.3110, Fid loss : 0.25
# Epochs: 1,  Loss : 4.2765, Fid loss : 0.265625
# Epochs: 1,  Loss : 0.7604, Fid loss : 0.171875
# Epochs: 1,  Loss : 3.4968, Fid loss : 0.203125
# Epochs: 1,  Loss : 0.3075, Fid loss : 0.25
# Epochs: 1,  Loss : 0.1788, Fid loss : 0.234375
# Epochs: 1,  Loss : 1.0691, Fid loss : 0.15625
# Epochs: 1,  Loss : 3.6843, Fid loss : 0.15625
# Epochs: 1,  Loss : 0.8147, Fid loss : 0.28125
# Epochs: 1,  Loss : 11.6725, Fid loss : 0.265625
# Epochs: 1,  Loss : 0.3237, Fid loss : 0.171875
# Epochs: 1,  Loss : 0.6751, Fid loss : 0.3125
# Epochs: 1,  Loss : 3.9005, Fid loss : 0.421875
# Epochs: 1,  Loss : 1.7144, Fid loss : 0.265625
# Epochs: 1,  Loss : 0.4528, Fid loss : 0.359375
# Epochs: 1,  Loss : 5.9824, Fid loss : 0.1875
# Epochs: 1,  Loss : 1.2107, Fid loss : 0.203125
# Epochs: 1,  Loss : 0.6981, Fid loss : 0.265625
# Epochs: 1,  Loss : 1.1812, Fid loss : 0.3125
# Epochs: 1,  Loss : 2.9816, Fid loss : 0.171875
# Epochs: 1,  Loss : 2.9261, Fid loss : 0.15625
# Epochs: 1,  Loss : 2.1552, Fid loss : 0.34375
# Epochs: 1,  Loss : 1.0947, Fid loss : 0.296875
# Epochs: 1,  Loss : 0.5935, Fid loss : 0.25
# Epochs: 1,  Loss : 6.2631, Fid loss : 0.328125
# Epochs: 1,  Loss : 18.8309, Fid loss : 0.3125
# Epochs: 1,  Loss : 0.3939, Fid loss : 0.09375
# Epochs: 1,  Loss : 1.7747, Fid loss : 0.109375
# Epochs: 1,  Loss : 1.0157, Fid loss : 0.203125
# Epochs: 1,  Loss : 0.6625, Fid loss : 0.140625
# Epochs: 1,  Loss : 1.0460, Fid loss : 0.28125
# Epochs: 1,  Loss : 6.5971, Fid loss : 0.390625
# Epochs: 1,  Loss : 1.2884, Fid loss : 0.15625
# Epochs: 1,  Loss : 0.1976, Fid loss : 0.1875
# Epochs: 1,  Loss : 0.3186, Fid loss : 0.203125
# Epochs: 1,  Loss : 0.7088, Fid loss : 0.359375
# Epochs: 1,  Loss : 2.1126, Fid loss : 0.453125
# Epochs: 1,  Loss : 1.5661, Fid loss : 0.09375
# Epochs: 1,  Loss : 0.7485, Fid loss : 0.203125
# Epochs: 1,  Loss : 0.3296, Fid loss : 0.3125
# Epochs: 1,  Loss : 0.8311, Fid loss : 0.5
# Epochs: 1,  Loss : 2.6665, Fid loss : 0.4375
# Epochs: 1,  Loss : 0.8580, Fid loss : 0.3125
# Epochs: 1,  Loss : 0.2163, Fid loss : 0.328125
# Epochs: 1,  Loss : 0.9955, Fid loss : 0.296875
# Epochs: 1,  Loss : 3.8380, Fid loss : 0.296875
# Epochs: 1,  Loss : 0.3600, Fid loss : 0.171875
# Epochs: 1,  Loss : 2.8805, Fid loss : 0.28125
# Epochs: 1,  Loss : 1.0923, Fid loss : 0.28125
# Epochs: 1,  Loss : 0.8446, Fid loss : 0.265625
# Epochs: 1,  Loss : 1.1332, Fid loss : 0.125
# Epochs: 1,  Loss : 0.1876, Fid loss : 0.21875
# Epochs: 1,  Loss : 1.9534, Fid loss : 0.265625
# Epochs: 1,  Loss : 0.6494, Fid loss : 0.140625
# Epochs: 1,  Loss : 9.9718, Fid loss : 0.328125
# Epochs: 1,  Loss : 0.1624, Fid loss : 0.125
# Epochs: 1,  Loss : 2.8552, Fid loss : 0.484375
# Epochs: 1,  Loss : 6.5893, Fid loss : 0.234375
# Epochs: 1,  Loss : 0.3856, Fid loss : 0.109375
# Epochs: 1,  Loss : 0.3416, Fid loss : 0.171875
# Epochs: 1,  Loss : 8.1956, Fid loss : 0.28125
# Epochs: 1,  Loss : 1.7604, Fid loss : 0.28125
# Epochs: 1,  Loss : 1.9316, Fid loss : 0.28125
# Epochs: 1,  Loss : 0.8547, Fid loss : 0.25
# Epochs: 1,  Loss : 0.6966, Fid loss : 0.1875
# Epochs: 1,  Loss : 0.5767, Fid loss : 0.21875
# Epochs: 1,  Loss : 0.3438, Fid loss : 0.21875
# Epochs: 1,  Loss : 6.1488, Fid loss : 0.3125
# Epochs: 1,  Loss : 0.1554, Fid loss : 0.28125
# Epochs: 1,  Loss : 0.9886, Fid loss : 0.265625
# Epochs: 1,  Loss : 1.2987, Fid loss : 0.3125
# Epochs: 1,  Loss : 0.6593, Fid loss : 0.46875
# Epochs: 1,  Loss : 13.5607, Fid loss : 0.296875
# Epochs: 1,  Loss : 0.2513, Fid loss : 0.203125
# Epochs: 1,  Loss : 0.1567, Fid loss : 0.265625
# Epochs: 1,  Loss : 5.3276, Fid loss : 0.28125
# Epochs: 1,  Loss : 4.5466, Fid loss : 0.265625
# Epochs: 1,  Loss : 0.2413, Fid loss : 0.28125
# Epochs: 1,  Loss : 2.5126, Fid loss : 0.1875
# Epochs: 1,  Loss : 3.4110, Fid loss : 0.328125
# Epochs: 1,  Loss : 0.3261, Fid loss : 0.21875
# Epochs: 1,  Loss : 0.4996, Fid loss : 0.265625
# Epochs: 1,  Loss : 6.6350, Fid loss : 0.21875
# Epochs: 1,  Loss : 1.2657, Fid loss : 0.1875
# Epochs: 1,  Loss : 0.7912, Fid loss : 0.203125
# Epochs: 1,  Loss : 10.0460, Fid loss : 0.171875
# Epochs: 1,  Loss : 3.1234, Fid loss : 0.296875
# Epochs: 1,  Loss : 0.2294, Fid loss : 0.3125
# Epochs: 1,  Loss : 0.4274, Fid loss : 0.390625
# Epochs: 1,  Loss : 0.4013, Fid loss : 0.1875
# Epochs: 1,  Loss : 1.5292, Fid loss : 0.265625
# Epochs: 1,  Loss : 2.8208, Fid loss : 0.265625
# Epochs: 1,  Loss : 1.4651, Fid loss : 0.265625
# Epochs: 1,  Loss : 0.5498, Fid loss : 0.265625
# Epochs: 1,  Loss : 1.6422, Fid loss : 0.125
# Epochs: 1,  Loss : 1.1457, Fid loss : 0.390625
# Epochs: 1,  Loss : 0.4560, Fid loss : 0.21875
# Epochs: 1,  Loss : 0.4285, Fid loss : 0.296875
# Epochs: 1,  Loss : 1.8847, Fid loss : 0.359375
# Epochs: 1,  Loss : 0.1887, Fid loss : 0.328125
# Epochs: 1,  Loss : 5.5326, Fid loss : 0.28125
# Epochs: 1,  Loss : 2.1829, Fid loss : 0.171875
# Epochs: 1,  Loss : 6.0915, Fid loss : 0.265625
# Epochs: 1,  Loss : 0.6203, Fid loss : 0.140625
# Epochs: 1,  Loss : 3.5960, Fid loss : 0.5625
# Epochs: 1,  Loss : 0.2624, Fid loss : 0.3125
# Epochs: 1,  Loss : 0.7215, Fid loss : 0.25
# Epochs: 1,  Loss : 0.4121, Fid loss : 0.390625
# Epochs: 1,  Loss : 2.2017, Fid loss : 0.234375
# Epochs: 1,  Loss : 0.8976, Fid loss : 0.28125
# Epochs: 1,  Loss : 0.5650, Fid loss : 0.21875
# Epochs: 1,  Loss : 1.5961, Fid loss : 0.125
# Epochs: 1,  Loss : 0.1617, Fid loss : 0.28125
# Epochs: 1,  Loss : 0.5686, Fid loss : 0.453125
# Epochs: 1,  Loss : 0.6295, Fid loss : 0.171875
# Epochs: 1,  Loss : 0.6672, Fid loss : 0.28125
# Epochs: 1,  Loss : 1.4825, Fid loss : 0.40625
# Epochs: 1,  Loss : 3.4485, Fid loss : 0.1875
# Epochs: 1,  Loss : 2.6513, Fid loss : 0.25
# Epochs: 1,  Loss : 4.0788, Fid loss : 0.15625
# Epochs: 1,  Loss : 0.7120, Fid loss : 0.328125
# Epochs: 1,  Loss : 0.3073, Fid loss : 0.1875
# Epochs: 1,  Loss : 2.2160, Fid loss : 0.265625
# Epochs: 1,  Loss : 1.0511, Fid loss : 0.25
# Epochs: 1,  Loss : 4.8568, Fid loss : 0.140625
# Epochs: 1,  Loss : 2.8250, Fid loss : 0.125
# Epochs: 1,  Loss : 0.5490, Fid loss : 0.25
# Epochs: 1,  Loss : 0.2111, Fid loss : 0.234375
# Epochs: 1,  Loss : 1.1214, Fid loss : 0.4375
# Epochs: 1,  Loss : 1.3208, Fid loss : 0.453125
# Epochs: 1,  Loss : 0.2994, Fid loss : 0.265625
# Epochs: 1,  Loss : 0.6197, Fid loss : 0.296875
# Epochs: 1,  Loss : 4.0857, Fid loss : 0.21875
# Epochs: 1,  Loss : 1.2732, Fid loss : 0.234375
# Epochs: 1,  Loss : 0.7446, Fid loss : 0.203125
# Epochs: 1,  Loss : 0.4630, Fid loss : 0.265625
# Epochs: 1,  Loss : 1.3267, Fid loss : 0.25
# Epochs: 1,  Loss : 0.8371, Fid loss : 0.375
# Epochs: 1,  Loss : 1.6462, Fid loss : 0.515625
# Epochs: 1,  Loss : 0.2802, Fid loss : 0.3125
# Epochs: 1,  Loss : 0.4323, Fid loss : 0.375
# Epochs: 1,  Loss : 0.4851, Fid loss : 0.4375
# Epochs: 1,  Loss : 3.7902, Fid loss : 0.296875
# Epochs: 1,  Loss : 3.9176, Fid loss : 0.21875
# Epochs: 1,  Loss : 0.4213, Fid loss : 0.171875
# Epochs: 1,  Loss : 0.6004, Fid loss : 0.34375
# Epochs: 1,  Loss : 3.8913, Fid loss : 0.140625
# Epochs: 1,  Loss : 0.7780, Fid loss : 0.265625
# Epochs: 1,  Loss : 3.7130, Fid loss : 0.28125
# Epochs: 1,  Loss : 1.4882, Fid loss : 0.15625
# Epochs: 1,  Loss : 1.7021, Fid loss : 0.171875
# Epochs: 1,  Loss : 2.9681, Fid loss : 0.09375
# Epochs: 1,  Loss : 0.5027, Fid loss : 0.28125
# Epochs: 1,  Loss : 1.1334, Fid loss : 0.21875
# Epochs: 1,  Loss : 0.3240, Fid loss : 0.328125
# Epochs: 1,  Loss : 0.9659, Fid loss : 0.234375
# Epochs: 1,  Loss : 3.2054, Fid loss : 0.25
# Epochs: 1,  Loss : 0.3731, Fid loss : 0.21875
# Epochs: 1,  Loss : 6.1184, Fid loss : 0.296875
# Epochs: 1,  Loss : 3.5646, Fid loss : 0.265625
# Epochs: 1,  Loss : 1.3722, Fid loss : 0.453125
# Epochs: 1,  Loss : 0.7327, Fid loss : 0.1875
# Epochs: 1,  Loss : 0.9658, Fid loss : 0.328125
# Epochs: 1,  Loss : 0.5742, Fid loss : 0.3125
# Epochs: 1,  Loss : 0.7329, Fid loss : 0.296875
# Epochs: 1,  Loss : 2.6682, Fid loss : 0.421875
# Epochs: 1,  Loss : 0.9043, Fid loss : 0.140625
# Epochs: 1,  Loss : 5.1895, Fid loss : 0.265625
# Epochs: 1,  Loss : 3.2206, Fid loss : 0.140625
# Epochs: 1,  Loss : 1.2765, Fid loss : 0.1875
# Epochs: 1,  Loss : 0.7117, Fid loss : 0.265625
# Epochs: 1,  Loss : 2.0988, Fid loss : 0.203125
# Epochs: 1,  Loss : 7.2894, Fid loss : 0.34375
# Epochs: 1,  Loss : 2.4179, Fid loss : 0.21875
# Epochs: 1,  Loss : 1.1097, Fid loss : 0.296875
# Epochs: 1,  Loss : 1.8984, Fid loss : 0.34375
# Epochs: 1,  Loss : 0.6886, Fid loss : 0.296875
# Epochs: 1,  Loss : 3.4664, Fid loss : 0.09375
# Epochs: 1,  Loss : 0.8154, Fid loss : 0.203125
# Epochs: 1,  Loss : 0.9576, Fid loss : 0.234375
# Epochs: 1,  Loss : 0.4846, Fid loss : 0.21875
# Epochs: 1,  Loss : 1.7896, Fid loss : 0.40625
# Epochs: 1,  Loss : 0.2027, Fid loss : 0.40625
# Epochs: 1,  Loss : 7.0847, Fid loss : 0.390625
# Epochs: 1,  Loss : 0.2498, Fid loss : 0.1875
# Epochs: 1,  Loss : 5.3437, Fid loss : 0.375
# Epochs: 1,  Loss : 3.2886, Fid loss : 0.203125
# Epochs: 1,  Loss : 4.6197, Fid loss : 0.203125
# Epochs: 1,  Loss : 0.8523, Fid loss : 0.296875
# Epochs: 1,  Loss : 2.3280, Fid loss : 0.390625
# Epochs: 1,  Loss : 0.1533, Fid loss : 0.59375
# Epochs: 1,  Loss : 3.9880, Fid loss : 0.15625
# Epochs: 1,  Loss : 0.2705, Fid loss : 0.125
# Epochs: 1,  Loss : 4.0274, Fid loss : 0.28125
# Epochs: 1,  Loss : 3.6651, Fid loss : 0.3125
# Epochs: 1,  Loss : 1.6662, Fid loss : 0.203125
# Epochs: 1,  Loss : 2.7452, Fid loss : 0.203125
# Epochs: 1,  Loss : 5.8939, Fid loss : 0.234375
# Epochs: 1,  Loss : 2.8993, Fid loss : 0.234375
# Epochs: 1,  Loss : 2.4823, Fid loss : 0.390625
# Epochs: 1,  Loss : 2.3603, Fid loss : 0.234375
# Epochs: 1,  Loss : 1.9609, Fid loss : 0.3125
# Epochs: 1,  Loss : 1.8915, Fid loss : 0.109375
# Epochs: 1,  Loss : 0.3404, Fid loss : 0.234375
# Epochs: 1,  Loss : 0.8954, Fid loss : 0.203125
# Epochs: 1,  Loss : 6.2574, Fid loss : 0.234375
# Epochs: 1,  Loss : 1.0980, Fid loss : 0.171875
# Epochs: 1,  Loss : 0.9671, Fid loss : 0.15625
# Epochs: 1,  Loss : 0.2288, Fid loss : 0.421875
# Epochs: 1,  Loss : 0.6478, Fid loss : 0.203125
# Epochs: 1,  Loss : 4.0701, Fid loss : 0.5625
# Epochs: 1,  Loss : 0.1711, Fid loss : 0.140625
# Epochs: 1,  Loss : 1.5165, Fid loss : 0.21875
# Epochs: 1,  Loss : 0.8977, Fid loss : 0.203125
# Epochs: 1,  Loss : 1.0054, Fid loss : 0.1875
# Epochs: 1,  Loss : 5.0217, Fid loss : 0.203125
# Epochs: 1,  Loss : 1.1388, Fid loss : 0.109375
# Epochs: 1,  Loss : 1.5397, Fid loss : 0.3125
# Epochs: 1,  Loss : 3.5719, Fid loss : 0.125
# Epochs: 1,  Loss : 0.4018, Fid loss : 0.140625
# Epochs: 1,  Loss : 3.2505, Fid loss : 0.203125
# Epochs: 1,  Loss : 1.1312, Fid loss : 0.34375
# Epochs: 1,  Loss : 1.9503, Fid loss : 0.21875
# Epochs: 1,  Loss : 0.9678, Fid loss : 0.375
# Epochs: 1,  Loss : 1.9636, Fid loss : 0.296875
# Epochs: 1,  Loss : 2.1607, Fid loss : 0.25
# Epochs: 1,  Loss : 1.2054, Fid loss : 0.3125
# Epochs: 1,  Loss : 3.8153, Fid loss : 0.171875
# Epochs: 1,  Loss : 1.7880, Fid loss : 0.28125
# Epochs: 1,  Loss : 1.2630, Fid loss : 0.21875
# Epochs: 1,  Loss : 0.4548, Fid loss : 0.25
# Epochs: 1,  Loss : 0.8496, Fid loss : 0.40625
# Epochs: 1,  Loss : 0.2051, Fid loss : 0.453125
# Epochs: 1,  Loss : 0.3681, Fid loss : 0.1875
# Epochs: 1,  Loss : 1.3353, Fid loss : 0.390625
# Epochs: 1,  Loss : 6.8589, Fid loss : 0.3125
# Epochs: 1,  Loss : 0.4676, Fid loss : 0.28125
# Epochs: 1,  Loss : 0.3469, Fid loss : 0.125
# Epochs: 1,  Loss : 8.5709, Fid loss : 0.265625
# Epochs: 1,  Loss : 1.3078, Fid loss : 0.203125
# Epochs: 1,  Loss : 1.4620, Fid loss : 0.3125
# Epochs: 1,  Loss : 0.8252, Fid loss : 0.46875
# Epochs: 1,  Loss : 0.9825, Fid loss : 0.484375
# Epochs: 1,  Loss : 1.0625, Fid loss : 0.21875
# Epochs: 1,  Loss : 2.1905, Fid loss : 0.140625
# Epochs: 1,  Loss : 3.3206, Fid loss : 0.328125
# Epochs: 1,  Loss : 3.6450, Fid loss : 0.265625
# Epochs: 1,  Loss : 0.1297, Fid loss : 0.140625
# Epochs: 1,  Loss : 16.5901, Fid loss : 0.3125
# Epochs: 1,  Loss : 1.2711, Fid loss : 0.15625
# Epochs: 1,  Loss : 0.2873, Fid loss : 0.234375
# Epochs: 1,  Loss : 0.3502, Fid loss : 0.375
# Epochs: 1,  Loss : 1.8961, Fid loss : 0.28125
# Epochs: 1,  Loss : 0.5708, Fid loss : 0.203125
# Epochs: 1,  Loss : 0.5854, Fid loss : 0.46875
# Epochs: 1,  Loss : 2.5760, Fid loss : 0.375
# Epochs: 1,  Loss : 0.7773, Fid loss : 0.234375
# Epochs: 1,  Loss : 1.2975, Fid loss : 0.1875
# Epochs: 1,  Loss : 4.4937, Fid loss : 0.21875
# Epochs: 1,  Loss : 1.4218, Fid loss : 0.203125
# Epochs: 1,  Loss : 3.6258, Fid loss : 0.265625
# Epochs: 1,  Loss : 0.8905, Fid loss : 0.25
# Epochs: 1,  Loss : 2.2622, Fid loss : 0.171875
# Epochs: 1,  Loss : 1.4235, Fid loss : 0.203125
# Epochs: 1,  Loss : 4.4472, Fid loss : 0.296875
# Epochs: 1,  Loss : 1.9203, Fid loss : 0.375
# Epochs: 1,  Loss : 0.3262, Fid loss : 0.21875
# Epochs: 1,  Loss : 1.2204, Fid loss : 0.203125
# Epochs: 1,  Loss : 0.2286, Fid loss : 0.21875
# Epochs: 1,  Loss : 2.3762, Fid loss : 0.234375
# Epochs: 1,  Loss : 3.4408, Fid loss : 0.09375
# Epochs: 1,  Loss : 3.7143, Fid loss : 0.171875
# Epochs: 1,  Loss : 5.0447, Fid loss : 0.28125
# Epochs: 1,  Loss : 0.8603, Fid loss : 0.28125
# Epochs: 1,  Loss : 2.3357, Fid loss : 0.40625
# Epochs: 1,  Loss : 3.1085, Fid loss : 0.25
# Epochs: 1,  Loss : 0.5060, Fid loss : 0.15625
# Epochs: 1,  Loss : 1.4933, Fid loss : 0.3125
# Epochs: 1,  Loss : 0.2080, Fid loss : 0.203125
# Epochs: 1,  Loss : 0.4290, Fid loss : 0.21875
# Epochs: 1,  Loss : 4.3941, Fid loss : 0.40625
# Epochs: 1,  Loss : 0.2428, Fid loss : 0.234375
# Epochs: 1,  Loss : 0.1134, Fid loss : 0.171875
# Epochs: 1,  Loss : 0.2849, Fid loss : 0.265625
# Epochs: 1,  Loss : 1.6086, Fid loss : 0.25
# Epochs: 1,  Loss : 2.2820, Fid loss : 0.078125
# Epochs: 1,  Loss : 0.7797, Fid loss : 0.296875
# Epochs: 1,  Loss : 0.7271, Fid loss : 0.1875
# Epochs: 1,  Loss : 0.6359, Fid loss : 0.1875
# Epochs: 1,  Loss : 5.8269, Fid loss : 0.328125
# Epochs: 1,  Loss : 0.3146, Fid loss : 0.34375
# Epochs: 1,  Loss : 2.5173, Fid loss : 0.3125
# Epochs: 1,  Loss : 0.4582, Fid loss : 0.3125
# Epochs: 1,  Loss : 1.5132, Fid loss : 0.296875
# Epochs: 1,  Loss : 2.4007, Fid loss : 0.203125
# Epochs: 1,  Loss : 0.5143, Fid loss : 0.296875
# Epochs: 1,  Loss : 0.2832, Fid loss : 0.21875
# Epochs: 1,  Loss : 0.4776, Fid loss : 0.28125
# Epochs: 1,  Loss : 0.2145, Fid loss : 0.3125
# Epochs: 1,  Loss : 0.6925, Fid loss : 0.21875
# Epochs: 1,  Loss : 1.2267, Fid loss : 0.28125
# Epochs: 1,  Loss : 4.8977, Fid loss : 0.375
# Epochs: 1,  Loss : 0.4856, Fid loss : 0.328125
# Epochs: 1,  Loss : 0.6689, Fid loss : 0.1875
# Epochs: 1,  Loss : 0.6430, Fid loss : 0.15625
# Epochs: 1,  Loss : 1.2662, Fid loss : 0.15625
# Epochs: 1,  Loss : 0.9686, Fid loss : 0.28125
# Epochs: 1,  Loss : 1.4541, Fid loss : 0.3125
# Epochs: 1,  Loss : 1.8927, Fid loss : 0.265625
# Epochs: 1,  Loss : 9.8685, Fid loss : 0.359375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 5
#       3 Y = Y.detach().numpy()
#       4 token, _ = gpt.generate(1, max_gate, TEM)
# ----> 5 states = state_subsequnce(*token, num_qubits, X)
#       6 energy = get_svm_acc(states, Y, GAMMA) - 1
#       7 energy_ten = torch.tensor(energy[None,:])
#
# Cell In[8], line 9, in state_subsequnce(token, num_qubits, data_set)
#       7         sub_token = token[:i]
#       8         for data in data_set:
# ----> 9             state = quantum_circuit(sub_token, num_qubits, data)
#      10             states.append(state)
#      11 return np.array(states).reshape(-1, data_set.shape[0], num_qubits**2)
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\pennylane\workflow\qnode.py:905, in QNode.__call__(self, *args, **kwargs)
#     903 if qml.capture.enabled():
#     904     return capture_qnode(self, *args, **kwargs)
# --> 905 return self._impl_call(*args, **kwargs)
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\pennylane\workflow\qnode.py:881, in QNode._impl_call(self, *args, **kwargs)
#     878 # Calculate the classical jacobians if necessary
#     879 self._transform_program.set_classical_component(self, args, kwargs)
# --> 881 res = qml.execute(
#     882     (tape,),
#     883     device=self.device,
#     884     diff_method=self.diff_method,
#     885     interface=interface,
#     886     transform_program=self._transform_program,
#     887     gradient_kwargs=self.gradient_kwargs,
#     888     **self.execute_kwargs,
#     889 )
#     890 res = res[0]
#     892 # convert result to the interface in case the qfunc has no parameters
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\pennylane\workflow\execution.py:232, in execute(tapes, device, diff_method, interface, transform_program, inner_transform, config, grad_on_execution, gradient_kwargs, cache, cachesize, max_diff, device_vjp, mcm_config, gradient_fn)
#     229 if transform_program.is_informative:
#     230     return post_processing(tapes)
# --> 232 results = run(tapes, device, config, inner_transform)
#     233 return post_processing(results)
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\pennylane\workflow\run.py:287, in run(tapes, device, config, inner_transform_program)
#     278 no_interface_boundary_required = (
#     279     config.interface == Interface.NUMPY
#     280     or config.gradient_method
#    (...)
#     284     }
#     285 )
#     286 if no_interface_boundary_required:
# --> 287     results = inner_execute(tapes)
#     288     return results
#     290 # TODO: Prune once support for tf-autograph is dropped
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\pennylane\workflow\run.py:247, in _make_inner_execute.<locals>.inner_execute(tapes)
#     244 transformed_tapes, transform_post_processing = inner_transform(tapes)
#     246 if transformed_tapes:
# --> 247     results = device.execute(transformed_tapes, execution_config=execution_config)
#     248 else:
#     249     results = ()
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\pennylane\devices\modifiers\simulator_tracking.py:30, in _track_execute.<locals>.execute(self, circuits, execution_config)
#      28 @wraps(untracked_execute)
#      29 def execute(self, circuits, execution_config=DefaultExecutionConfig):
# ---> 30     results = untracked_execute(self, circuits, execution_config)
#      31     if isinstance(circuits, QuantumScript):
#      32         batch = (circuits,)
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\pennylane\devices\modifiers\single_tape_support.py:32, in _make_execute.<locals>.execute(self, circuits, execution_config)
#      30     is_single_circuit = True
#      31     circuits = (circuits,)
# ---> 32 results = batch_execute(self, circuits, execution_config)
#      33 return results[0] if is_single_circuit else results
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\pennylane\logging\decorators.py:61, in log_string_debug_func.<locals>.wrapper_entry(*args, **kwargs)
#      54     s_caller = "::L".join(
#      55         [str(i) for i in inspect.getouterframes(inspect.currentframe(), 2)[1][1:3]]
#      56     )
#      57     lgr.debug(
#      58         f"Calling {f_string} from {s_caller}",
#      59         **_debug_log_kwargs,
#      60     )
# ---> 61 return func(*args, **kwargs)
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\pennylane\devices\default_qubit.py:630, in DefaultQubit.execute(self, circuits, execution_config)
#     627 prng_keys = [self.get_prng_keys()[0] for _ in range(len(circuits))]
#     629 if max_workers is None:
# --> 630     return tuple(
#     631         _simulate_wrapper(
#     632             c,
#     633             {
#     634                 "rng": self._rng,
#     635                 "debugger": self._debugger,
#     636                 "interface": interface,
#     637                 "state_cache": self._state_cache,
#     638                 "prng_key": _key,
#     639                 "mcm_method": execution_config.mcm_config.mcm_method,
#     640                 "postselect_mode": execution_config.mcm_config.postselect_mode,
#     641             },
#     642         )
#     643         for c, _key in zip(circuits, prng_keys)
#     644     )
#     646 vanilla_circuits = convert_to_numpy_parameters(circuits)[0]
#     647 seeds = self._rng.integers(2**31 - 1, size=len(vanilla_circuits))
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\pennylane\devices\default_qubit.py:631, in <genexpr>(.0)
#     627 prng_keys = [self.get_prng_keys()[0] for _ in range(len(circuits))]
#     629 if max_workers is None:
#     630     return tuple(
# --> 631         _simulate_wrapper(
#     632             c,
#     633             {
#     634                 "rng": self._rng,
#     635                 "debugger": self._debugger,
#     636                 "interface": interface,
#     637                 "state_cache": self._state_cache,
#     638                 "prng_key": _key,
#     639                 "mcm_method": execution_config.mcm_config.mcm_method,
#     640                 "postselect_mode": execution_config.mcm_config.postselect_mode,
#     641             },
#     642         )
#     643         for c, _key in zip(circuits, prng_keys)
#     644     )
#     646 vanilla_circuits = convert_to_numpy_parameters(circuits)[0]
#     647 seeds = self._rng.integers(2**31 - 1, size=len(vanilla_circuits))
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\pennylane\devices\default_qubit.py:918, in _simulate_wrapper(circuit, kwargs)
#     917 def _simulate_wrapper(circuit, kwargs):
# --> 918     return simulate(circuit, **kwargs)
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\pennylane\logging\decorators.py:61, in log_string_debug_func.<locals>.wrapper_entry(*args, **kwargs)
#      54     s_caller = "::L".join(
#      55         [str(i) for i in inspect.getouterframes(inspect.currentframe(), 2)[1][1:3]]
#      56     )
#      57     lgr.debug(
#      58         f"Calling {f_string} from {s_caller}",
#      59         **_debug_log_kwargs,
#      60     )
# ---> 61 return func(*args, **kwargs)
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\pennylane\devices\qubit\simulate.py:357, in simulate(circuit, debugger, state_cache, **execution_kwargs)
#     354     return tuple(results)
#     356 ops_key, meas_key = jax_random_split(prng_key)
# --> 357 state, is_state_batched = get_final_state(
#     358     circuit, debugger=debugger, prng_key=ops_key, **execution_kwargs
#     359 )
#     360 if state_cache is not None:
#     361     state_cache[circuit.hash] = state
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\pennylane\logging\decorators.py:61, in log_string_debug_func.<locals>.wrapper_entry(*args, **kwargs)
#      54     s_caller = "::L".join(
#      55         [str(i) for i in inspect.getouterframes(inspect.currentframe(), 2)[1][1:3]]
#      56     )
#      57     lgr.debug(
#      58         f"Calling {f_string} from {s_caller}",
#      59         **_debug_log_kwargs,
#      60     )
# ---> 61 return func(*args, **kwargs)
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\pennylane\devices\qubit\simulate.py:190, in get_final_state(circuit, debugger, **execution_kwargs)
#     188 if isinstance(op, MidMeasureMP):
#     189     prng_key, key = jax_random_split(prng_key)
# --> 190 state = apply_operation(
#     191     op,
#     192     state,
#     193     is_state_batched=is_state_batched,
#     194     debugger=debugger,
#     195     prng_key=key,
#     196     tape_shots=circuit.shots,
#     197     **execution_kwargs,
#     198 )
#     199 # Handle postselection on mid-circuit measurements
#     200 if isinstance(op, qml.Projector):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\functools.py:909, in singledispatch.<locals>.wrapper(*args, **kw)
#     905 if not args:
#     906     raise TypeError(f'{funcname} requires at least '
#     907                     '1 positional argument')
# --> 909 return dispatch(args[0].__class__)(*args, **kw)
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\pennylane\devices\qubit\apply_operation.py:231, in apply_operation(op, state, is_state_batched, debugger, **_)
#     165 @singledispatch
#     166 def apply_operation(
#     167     op: qml.operation.Operator,
#    (...)
#     171     **_,
#     172 ):
#     173     """Apply and operator to a given state.
#     174
#     175     Args:
#    (...)
#     229
#     230     """
# --> 231     return _apply_operation_default(op, state, is_state_batched, debugger)
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\pennylane\devices\qubit\apply_operation.py:241, in _apply_operation_default(op, state, is_state_batched, debugger)
#     235 """The default behaviour of apply_operation, accessed through the standard dispatch
#     236 of apply_operation, as well as conditionally in other dispatches."""
#     237 if (
#     238     len(op.wires) < EINSUM_OP_WIRECOUNT_PERF_THRESHOLD
#     239     and math.ndim(state) < EINSUM_STATE_WIRECOUNT_PERF_THRESHOLD
#     240 ) or (op.batch_size and is_state_batched):
# --> 241     return apply_operation_einsum(op, state, is_state_batched=is_state_batched)
#     242 return apply_operation_tensordot(op, state, is_state_batched=is_state_batched)
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\pennylane\devices\qubit\apply_operation.py:80, in apply_operation_einsum(op, state, is_state_batched)
#      78     mat = qml.math.cast_like(op.matrix(), state)
#      79 else:
# ---> 80     mat = op.matrix() + 0j
#      82 total_indices = len(state.shape) - is_state_batched
#      83 num_indices = len(op.wires)
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\pennylane\operation.py:810, in Operator.matrix(self, wire_order)
#     790 def matrix(self, wire_order: Optional[WiresLike] = None) -> TensorLike:
#     791     r"""Representation of the operator as a matrix in the computational basis.
#     792
#     793     If ``wire_order`` is provided, the numerical representation considers the position of the
#    (...)
#     808         tensor_like: matrix representation
#     809     """
# --> 810     canonical_matrix = self.compute_matrix(*self.parameters, **self.hyperparameters)
#     812     if (
#     813         wire_order is None
#     814         or self.wires == Wires(wire_order)
#    (...)
#     818         )
#     819     ):
#     820         return canonical_matrix
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\pennylane\ops\qubit\parametric_ops_single_qubit.py:210, in RY.compute_matrix(theta)
#     208 c = (1 + 0j) * c
#     209 s = (1 + 0j) * s
# --> 210 return qml.math.stack([stack_last([c, -s]), stack_last([s, c])], axis=-2)
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\pennylane\math\multi_dispatch.py:153, in multi_dispatch.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     150 interface = interface or get_interface(*dispatch_args)
#     151 kwargs["like"] = interface
# --> 153 return fn(*args, **kwargs)
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\pennylane\math\multi_dispatch.py:504, in stack(values, axis, like)
#     475 """Stack a sequence of tensors along the specified axis.
#     476
#     477 .. warning::
#    (...)
#     501        [5.00e+00, 8.00e+00, 1.01e+02]], dtype=float32)>
#     502 """
#     503 values = np.coerce(values, like=like)
# --> 504 return np.stack(values, axis=axis, like=like)
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\autoray\autoray.py:81, in do(fn, like, *args, **kwargs)
#      79 backend = _choose_backend(fn, args, kwargs, like=like)
#      80 func = get_lib_fn(backend, fn)
# ---> 81 return func(*args, **kwargs)
#
# File c:\Users\detra\OneDrive\Desktop\Quantum\GQE\Decoder\.venv\Lib\site-packages\autoray\autoray.py:1331, in translate_wrapper.<locals>.translated_function(*args, **kwargs)
#    1328 for key, value in translation.items():
#    1329     new_kwargs[value[0]] = value[1]
# -> 1331 return fn(**new_kwargs)
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(15,6))
plt.plot(train_losses)
plt.title("loss history")
plt.yscale("log")

# %%
plt.figure(figsize=(15,6))
plt.plot(fid_losses)
plt.title("training fidelity loss")
# Out:
# Text(0.5, 1.0, 'training fidelity loss')

# %%
# Out:
# Text(0.5, 1.0, 'evaluation loss')

# %%
plt.yscale('log')
plt.plot(ev_loss_history)
plt.title("evaluation loss")
plt.axhline(10, c='r', linestyle='--')

# %%
final_token, logit = model.token_generate(max_new_tokens = max_gate, temperature = .01, device = device)

# %%
from Qiskit.Circuit_generate import circuit_generator, get_tr_dist_matrix, get_fid_matrix, calculate_fidelity
c, _ = circuit_generator(final_token[0], n_qubits=num_qubits, data=X_batch[0], matching=False)

# %%
c.draw('mpl')
